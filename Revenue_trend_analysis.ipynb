# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df = pd.read_excel("C:/Users/sharm/Downloads/finance_dashboard_dummy_data.xlsx")

# %%
df
# Out:
#           Date MonthYear  Revenue  Expenses  Profit  Investment_Value  \
# 0   2017-01-01  Jan 2017   209934    166492   43442            974069
# 1   2017-02-01  Feb 2017   213788    134579   79209            998640
# 2   2017-03-01  Mar 2017   242041    176661   65380            984906
# 3   2017-04-01  Apr 2017   265121    203928   61193            975624
# 4   2017-05-01  May 2017   227511    168842   58669           1036747
# ..         ...       ...      ...       ...     ...               ...
# 99  2025-04-01  Apr 2025   379095    278586  100509           1323657
# 100 2025-05-01  May 2025   353013    204902  148111           1333059
# 101 2025-06-01  Jun 2025   363480    247846  115634           1318735
# 102 2025-07-01  Jul 2025   351592    234043  117549           1335495
# 103 2025-08-01  Aug 2025   328954    210190  118764           1359433
#
#      Salaries  Marketing    R&D  Admin  Others  Profit_Margin  \
# 0      102570      33056   8843  16648    5375       0.206932
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Convert to datetime
df['MonthYear_dt'] = pd.to_datetime(df['MonthYear'], format='%b %Y')

# Convert to numeric (e.g., number of months since a reference date)
df['MonthYear_num'] = (df['MonthYear_dt'].dt.year - 2000) * 12 + df['MonthYear_dt'].dt.month

X = df[['MonthYear_num']]
y = df['Revenue']

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Create future dataframe using the same feature name used in training
future = pd.DataFrame({'MonthYear_num': [13, 14, 15]})

# Predict
predictions = model.predict(future)
print("Next months revenue:", predictions)
# Out:
# Next months revenue: [-97154.73104662 -95612.56780113 -94070.40455564]
